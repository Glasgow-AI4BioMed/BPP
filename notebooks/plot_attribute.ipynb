# %%
import pandas as pd 

df = pd.read_csv("wandb_export_2022-12-05T22_07_34.030+00_00.csv")
df
# Out:
#                  Name     State Notes         User  Tags  \
# 0     breezy-sweep-10  finished     -  mengzaiqiao   NaN
# 1   twilight-sweep-10  finished     -  mengzaiqiao   NaN
# 2       lemon-sweep-9  finished     -  mengzaiqiao   NaN
# 3      expert-sweep-9  finished     -  mengzaiqiao   NaN
# 4      smooth-sweep-8  finished     -  mengzaiqiao   NaN
# ..                ...       ...   ...          ...   ...
# 75        icy-sweep-3  finished     -  mengzaiqiao   NaN
# 76      jolly-sweep-2  finished     -  mengzaiqiao   NaN
# 77    charmed-sweep-2  finished     -  mengzaiqiao   NaN
# 78    restful-sweep-1  finished     -  mengzaiqiao   NaN
# 79  wandering-sweep-1  finished     -  mengzaiqiao   NaN
#
#                      Created  Runtime     Sweep        dataset  drop_out  ...  \
# 0   2022-12-05T21:38:14.000Z      144  iizb8raw        Disease       1.0  ...
# 1   2022-12-05T21:36:32.000Z      185  wypb1wlr        Disease       1.0  ...
# ...

# %%
import seaborn as sns
sns.lineplot(data=df[df["model_name"]=="GCN"],x="drop_out",y="test_acc",hue="dataset", style="dataset", markers=True, palette="tab10", linewidth=2)
# Out:
# <AxesSubplot:xlabel='drop_out', ylabel='test_acc'>

# %%
sns.lineplot(data=df[df["model_name"]=="GCN"],x="drop_out",y="test_ndcg",hue="dataset", style="dataset", markers=True, palette="tab10", linewidth=2)
# Out:
# <AxesSubplot:xlabel='drop_out', ylabel='test_ndcg'>

# %%
sns.lineplot(data=df[df["model_name"]=="HGNN"],x="drop_out",y="test_acc",hue="dataset", style="dataset", markers=True, palette="tab10", linewidth=2)
# Out:
# <AxesSubplot:xlabel='drop_out', ylabel='test_acc'>

# %%
sns.lineplot(data=df[df["model_name"]=="HGNN"],x="drop_out",y="test_ndcg",hue="dataset", style="dataset", markers=True, palette="tab10", linewidth=2)
# Out:
# <AxesSubplot:xlabel='drop_out', ylabel='test_ndcg'>
